# %% [markdown]
# # 2. Phase field optimization
#
# Using the extracted point-based signals as input, we optimize the phase field by minimizing a combined loss function,
# \begin{equation}
# \mathcal{L}
# = \lambda_1 \mathcal{L}_\mathrm{data}
# + \lambda_2 \mathcal{L}_\mathrm{B.C.}
# + \lambda_3 \mathcal{L}_\mathrm{physics}
# + \lambda_4 \mathcal{L}_\mathrm{smooth}.
# \end{equation}
# Here, $\mathcal{L}_\mathrm{data}$, $\mathcal{L}_\mathrm{B.C.}$, $\mathcal{L}_\mathrm{physics}$, and $\mathcal{L}_\mathrm{smooth}$ denote the data loss, boundary condition loss, physics loss, and smoothing loss, respectively.
#
# The optimization is performed in three stages. In the first stage, only the data and boundary condition losses are used, while the physics and smoothing losses are disabled. In the second stage, the physics loss is activated, but the smoothing loss remains inactive. In the final stage, all loss terms are included.
#
# After the second stage, collocation points for the smoothing loss are sampled from the zero level set of the optimized phase field, and are subsequently used as input for the third stage of optimization.
#
# ##### Input:
# - `dat/pts_e_{shape}.npz` (edge/bulk signals)
# - `dat/pts_s_{shape}.npz` (inside/outside signals)
# - `dat/pts_p_{shape}.npz` (physics collocation points)
#
# ##### Intermediate:
# - `dat/pts_c_{shape}.npz` (smoothing collocation points)
#
# ##### Output:
# - `output/stage***/checkpoint***` (phase field log data)
# - `output/stage***/result.png`    (result summary)

# %%
import sys
import os
import numpy as np
from pathlib import Path

#### Add program source to sys.path ####
project_root = Path().resolve()
sys.path.append(str(project_root / "../../src"))
sys.path.append(str(project_root / "../src"))

# %% [markdown]
# #### Three-stage calculation of the phase field

# %%
from optimization import run_sim, sample_curv_points

#### Parameters ####
data_path = "../dat"
output_dir = "../output"
shape = "bud-11"
lambda_1 = 100000   # data loss
lambda_2 = 100000   # B.C. loss
lambda_3 = 1        # physics loss
lambda_4 = 10       # smoothing loss

#### Stage 1: lambda_3 = 0, lambda_4 = 0 ####
run_sim(
    data_path=data_path,
    output_dir=output_dir,
    shape=shape,
    sdf_pretrain="uniform",
    lambda_1=lambda_1,
    lambda_2=lambda_2,
    lambda_3=0, 
    lambda_4=0,
    num_steps=10000,
    stage = 0,
)

#### Stage 2: lambda_4 = 0 ####
run_sim(
    data_path=data_path,
    output_dir=output_dir,
    shape=shape,
    sdf_pretrain="checkpoint",
    lambda_1=lambda_1,
    lambda_2=lambda_2,
    lambda_3=lambda_3,
    lambda_4=0,
    num_steps=10000,
    stage = 1,
)

#### Sample smoothing loss collocation points ####
sample_curv_points(
    data_path=data_path,
    output_dir=output_dir,
    shape=shape,
    lambda_1=lambda_1,
    lambda_2=lambda_2,
    lambda_3=lambda_3,
    num_curv = 5000,
)

#### Stage 3 ####
run_sim(
    data_path=data_path,
    output_dir=output_dir,
    shape=shape,
    sdf_pretrain="checkpoint",
    lambda_1=lambda_1,
    lambda_2=lambda_2,
    lambda_3=lambda_3,
    lambda_4=lambda_4,
    num_steps=10000,
    stage = 2,
)
# Out:
# /mmfs1/gscratch/matsulab/sim/pinn-exploration-model/tutorial/output/stage1_100000_100000_1_0/checkpoint_10000
# Initial shape from: /mmfs1/gscratch/matsulab/sim/pinn-exploration-model/tutorial/output/stage1_100000_100000_1_0/checkpoint_10000
# Use pretrained data as initial condition...
# [bud-11] pretrain=checkpoint lambdas=(100000, 100000, 1, 10) -> /mmfs1/gscratch/matsulab/sim/pinn-exploration-model/tutorial/output/stage2_100000_100000_1_10
#   0%|          | 0/10000 [00:00<?, ?it/s]
# E0429 14:11:58.275667   68581 buffer_comparator.cc:150] Difference at 14845049: 0, expected -411.256
# E0429 14:11:58.281000   68581 buffer_comparator.cc:150] Difference at 16556317: 800, expected 461.393
# E0429 14:11:58.288400   68581 buffer_comparator.cc:150] Difference at 19202821: 5504, expected 8263.45
# E0429 14:11:58.294111   68581 buffer_comparator.cc:150] Difference at 21145613: -1024, expected -588.962
# E0429 14:11:58.410009   68581 buffer_comparator.cc:150] Difference at 14845049: 0, expected -411.256
# E0429 14:11:58.414964   68581 buffer_comparator.cc:150] Difference at 16556317: 800, expected 461.393
# E0429 14:11:58.423016   68581 buffer_comparator.cc:150] Difference at 19202821: 5504, expected 8263.45
# E0429 14:11:58.428788   68581 buffer_comparator.cc:150] Difference at 21145613: -1024, expected -588.962
# E0429 14:11:58.545965   68581 buffer_comparator.cc:150] Difference at 14845049: 0, expected -411.256
# E0429 14:11:58.551236   68581 buffer_comparator.cc:150] Difference at 16556317: 800, expected 461.393
# E0429 14:11:58.558927   68581 buffer_comparator.cc:150] Difference at 19202821: 5504, expected 8263.45
# E0429 14:11:58.564419   68581 buffer_comparator.cc:150] Difference at 21145613: -1024, expected -588.962
# E0429 14:11:58.679692   68581 buffer_comparator.cc:150] Difference at 14845049: 0, expected -411.256
# E0429 14:11:58.684642   68581 buffer_comparator.cc:150] Difference at 16556317: 800, expected 461.393
# E0429 14:11:58.691755   68581 buffer_comparator.cc:150] Difference at 19202821: 5504, expected 8263.45
# E0429 14:11:58.697451   68581 buffer_comparator.cc:150] Difference at 21145613: -1024, expected -588.962
# E0429 14:11:58.814582   68581 buffer_comparator.cc:150] Difference at 14845049: 0, expected -411.256
# E0429 14:11:58.819892   68581 buffer_comparator.cc:150] Difference at 16556317: 800, expected 461.393
# E0429 14:11:58.827458   68581 buffer_comparator.cc:150] Difference at 19202821: 5504, expected 8263.45
# E0429 14:11:58.833005   68581 buffer_comparator.cc:150] Difference at 21145613: -1024, expected -588.962
# E0429 14:11:58.949200   68581 buffer_comparator.cc:150] Difference at 14845049: -512, expected -411.256
# E0429 14:11:58.953358   68581 buffer_comparator.cc:150] Difference at 16250047: -4080, expected -4595.33
# E0429 14:11:58.954286   68581 buffer_comparator.cc:150] Difference at 16556317: 768, expected 461.393
# E0429 14:11:58.957496   68581 buffer_comparator.cc:150] Difference at 17692263: 1792, expected 2141.59
# E0429 14:11:58.961714   68581 buffer_comparator.cc:150] Difference at 19202821: 5632, expected 8263.45
# E0429 14:11:58.966525   68581 buffer_comparator.cc:150] Difference at 20858627: -1152, expected -1344.58
# E0429 14:11:59.629645   68581 buffer_comparator.cc:150] Difference at 14845049: -640, expected -411.256
# E0429 14:11:59.635007   68581 buffer_comparator.cc:150] Difference at 16556317: 736, expected 461.393
# E0429 14:11:59.638340   68581 buffer_comparator.cc:150] Difference at 17692263: 2432, expected 2141.59
# E0429 14:11:59.642912   68581 buffer_comparator.cc:150] Difference at 19202821: 6208, expected 8263.45
# E0429 14:11:59.648305   68581 buffer_comparator.cc:150] Difference at 21145613: -896, expected -588.962
# E0429 14:11:59.651255   68581 buffer_comparator.cc:150] Difference at 22138750: -26624, expected -30986.2
# Saved: /mmfs1/gscratch/matsulab/sim/pinn-exploration-model/tutorial/output/stage2_100000_100000_1_10/result.png

# %% [markdown]
# #### Visualization of the final phase field

# %%
from pinn.plot import visualize_cryoET_with_contours, visualize_phase
import tifffile as tiff
import matplotlib.pyplot as plt
from flax.training import checkpoints

# ==== Parameters =====
lambda_1 = 100000
lambda_2 = 100000
lambda_3 = 1
lambda_4 = 10
step = 10000
stage = 2
axis = "x"
shape = "bud-11"
slices = range(60, 120, 10)
expand_xy = None

# ==== Load checkpoint data =====
checkpoint_dir = f"../output/stage{stage}_{lambda_1}_{lambda_2}_{lambda_3}_{lambda_4}"
checkpoint_path = os.path.abspath(f"{checkpoint_dir}/checkpoint_{step}")
checkpoint_data = checkpoints.restore_checkpoint(ckpt_dir=checkpoint_path, target=None)
print(checkpoint_path)

# ===== Load cryoET data =====
tif_file_path = f"../dat/{shape}.tif"
cryoET_data = tiff.imread(tif_file_path)
cryoET_data = 1 - cryoET_data
grid_size = cryoET_data.shape[0]

# ==== Plot output =====
n = len(slices)
fig, axes = plt.subplots(3, n, figsize=(2.5*n, 2.5*3))

# --- row 1: cryoET + contour ---
for ax, slice_index in zip(axes[0], slices):
    visualize_cryoET_with_contours(
        ax, step, checkpoint_data, cryoET_data, grid_size=grid_size, 
        slice_index=slice_index, axis=axis, no_label=True, expand_xy=expand_xy,
    )

# --- row 2: phi ---
for ax, slice_index in zip(axes[1], slices):
    visualize_phase(
        ax, epsilon=0.05, checkpoint=checkpoint_data, component="phi", grid_size=grid_size,
        slice_index=slice_index, axis=axis, no_label=True, vmin=-1, vmax=1, expand_xy=expand_xy,
    )

# --- row 3: tension ---
for ax, slice_index in zip(axes[2], slices):
    visualize_phase(
        ax, epsilon=0.05, checkpoint=checkpoint_data, component="tension", grid_size=grid_size,
        slice_index=slice_index, axis=axis, no_label=True, vmin=0.0, vmax=1.0, expand_xy=expand_xy,
    )

plt.tight_layout()
plt.show()
# Out:
# /mmfs1/gscratch/matsulab/sim/pinn-exploration-model/tutorial/output/stage2_100000_100000_1_10/checkpoint_10000

# %%
import importlib
import optimization as optimization
import pinn.plot as plot
import pinn.train_curv as curv
importlib.reload(plot)
importlib.reload(curv)
importlib.reload(optimization)
# Out:
# <module 'optimization' from '/mmfs1/gscratch/matsulab/sim/pinn-exploration-model/tutorial/note/../src/optimization.py'>
