# %% [markdown]
# # 2. Phase field optimization
# Using the extracted point-based signals as input, we optimize the phase field. Each set of points contributes to different loss terms, namely data loss, boundary loss, and physics loss. The optimization is performed in two stages: first without the physics loss, and then with the physics loss included.
#
# ##### Input:
# - `dat/pts_e_lime_pm_1.npz` (edge/bulk signals)
# - `dat/pts_s_lime_pm_1.npz` (inside/outside signals)
# - `dat/pts_p_lime_pm_1.npz` (collocation points)
#
# ##### Output:
# -
